# %% [markdown]
# At first we mount google drive and install the required dependencies.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %ls
# Out:
# benchmarks.py    data/      export.py    models/             README.roboflow.txt  train.py
# CITATION.cff     datasets/  hubconf.py   pyproject.toml      README.zh-CN.md      tutorial.ipynb
# classify/        data.yaml  Lab04.ipynb  README.dataset.txt  requirements.txt     utils/
# CONTRIBUTING.md  detect.py  LICENSE      README.md           segment/             val.py

# %%
# %pip install -qr requirements.txt comet_ml
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.6/710.6 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.2/910.2 kB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.7/979.7 kB 36.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 11.1 MB/s eta 0:00:00

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 de62f93 Python-3.11.11 torch-2.5.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.2/107.7 GB disk)

# %% [markdown]
# ### 1. Train the model
# We train YOLOv5 model on some custom dataset from https://universe.roboflow.com/ds/jKA6DluL02?key=upakzFXQ1O.

# %%
# !git config --global user.email "gaia.volpi@studenti.unipd.it"
# !git config --global user.name "gaiavolpi"

# %%
# !git add .
# !git commit -m 'uploaded dataset + changes in the folder structure'
# Out:
# ^C
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@a18e8d36a963.(none)')
